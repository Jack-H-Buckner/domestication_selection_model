# %%
using FFTW
using Distributions
using Plots
using DSP
include("../two_populations_conservaiton_hatchery/Normal_population.jl")

include("../two_populations_conservaiton_hatchery/FFT_population.jl")
# Out:
# WARNING: replacing module Normal_population.
# WARNING: replacing module FFT_population.
# Main.FFT_population

# %%
function dynamics_Normal!(pop, pop_flow)
    # selection
    pop = Normal_population.selection!(pop)
    pop_flow = Normal_population.selection!(pop_flow)
    # print(pop_flow.N)
    # reproduction
    pop = Normal_population.reproduction!(pop, pop_flow)
    # dentisy dependence 
    pop = Normal_population.density_dependence!(pop)
    
    return pop
end 


function equilibrium_Normal!(pop, m, diff)
    pop_flow = Normal_population.population(m,0.5,1.0,s,Vle,2,[diff,Vle])
    for i in 1:500
        dynamics_Normal!(pop,pop_flow)
    end
    return pop
end
# Out:
# equilibrium_Normal! (generic function with 1 method)

# %%
function dynamics!(pop, dsn_flow,N_flow)
    # selection
    #FFT_population.selection!(pop)
    # flow
    #FFT_population.flow!(pop, dsn_flow,N_flow)
    
    # reproduction
    FFT_population.reproduction!(pop)
    # dentisy dependence 
    FFT_population.density_dependence!(pop)
    
end 


function equilibrium!(pop, dsn_flow,N_flow)
    for i in 1:500
        dynamics!(pop,dsn_flow,N_flow)
    end
end
# Out:
# equilibrium! (generic function with 1 method)

# %%
# parameters 
# fixed
r = 0.7
K = 1.0
s = 0.2
m = 0.1
Vle = 1.0
diff = 7
# Out:
# 7

# %%
pop1, dsn_flow = FFT_population.init_pop(diff,r,K,s)
Plots.plot(pop1.grid,pop1.values)
dynamics!(pop1,dsn_flow,m)
N_ls = zeros(100)
for i in 1:2
    Plots.plot!(pop1.grid,pop1.values)
    dynamics!(pop1,dsn_flow,m)
    N_ls[i] = pop1.N
end
Plots.plot!(pop1.grid,pop1.values)

# %%
include("../two_populations_conservaiton_hatchery/FFT_population.jl")
pop1, dsn_flow = FFT_population.init_pop(diff,r,K,s)
mean_fit, sd_fit,fit_cdf,fit_pdf = FFT_population.fittness(pop1)
Plots.plot(fit_pdf[:,2],fit_pdf[:,1])

dynamics!(pop1,dsn_flow,m)
N_ls = zeros(100)
for i in 1:50
    mean_fit, sd_fit,fit_cdf, fit_pdf = FFT_population.fittness(pop1)
    Plots.plot!(fit_pdf[:,2],fit_pdf[:,1])
    dynamics!(pop1,dsn_flow,m)
    N_ls[i] = pop1.N
end
mean_fit, sd_fit,fit_cdf, fit_pdf = FFT_population.fittness(pop1)
Plots.plot!(fit_pdf[:,2],fit_pdf[:,1], legend = false)
# Out:
# WARNING: replacing module FFT_population.

# %%
N = length(fit_cdf[:,2])
fittness_dsn = (fit_cdf[2:N,2] .- fit_cdf[1:(N-1),2]).*(fit_cdf[2:N,1] .- fit_cdf[1:(N-1),1])
Plots.plot(fit_cdf[1:(N-1),2], (fit_cdf[2:N,2] .- fit_cdf[1:(N-1),2]).*(fit_cdf[2:N,1] .- fit_cdf[1:(N-1),1]), legend = false)

# %%
x = 0:0.1:10
eq = zeros(length(x))
eqv = zeros(length(x))
eqN = zeros(length(x))
i = 0
for diff in x
    i +=1
    pop1, dsn_flow = FFT_population.init_pop(diff,r,K,s)
    equilibrium!(pop1, dsn_flow,m)
    eq[i] = sum(pop1.grid .* pop1.values)
    eqv[i] = sum(pop1.grid.^2 .* pop1.values) - eq[i]^2
end
Plots.plot(x,eq)
Plots.plot!(x,eqv)
Plots.plot!(x,eqN)

# %%
diff = 7.0
s = 0.1
i = 0
x = 0:0.01:1.0
m = length(x)
eq = zeros(m)
for N_flow in x
    i +=1
    pop1, dsn_flow = FFT_population.init_pop(diff,r,K,s)
    equilibrium!(pop1, dsn_flow,N_flow)
    eq[i] = pop1.N
end
Plots.plot(x,eq)

# %%
include("../two_populations_conservaiton_hatchery/Normal_population.jl")
m = 0.1
x = 0:0.25:10
eq = zeros(length(x))
eqv = zeros(length(x))
eq2 = zeros(length(x))
eqv2 = zeros(length(x))
i = 0
s = 0.5
for diff in x
    i+=1
    pop_N = Normal_population.population(1.0,r,K,s,Vle,2,[0,Vle])
    eq[i] = equilibrium_Normal!(pop_N, m, diff).moments[1]
    eqv[i] = equilibrium_Normal!(pop_N, m, diff).moments[2]
    eq2[i] = equilibrium_Normal2!(pop_N, m, diff).moments[1]
    eqv2[i] = equilibrium_Normal2!(pop_N, m, diff).moments[2]
end 
Plots.plot(x,eq)
Plots.plot!(x,eqv)
Plots.plot!(x,eq2)
Plots.plot!(x,eqv2)
# Out:
# WARNING: replacing module Normal_population.

# %%
diff = 6.0
s = 0.5
x = 0:0.001:0.2
eq = zeros(length(x))
eqv = zeros(length(x))
eqN = zeros(length(x))
i = 0

for m in x
    i+=1
    pop_N = Normal_population.population(5.0,r,K,s,Vle,2,[0,Vle])
    eq[i] = equilibrium_Normal!(pop_N, m, diff).moments[1]
    eqv[i] = equilibrium_Normal!(pop_N, m, diff).moments[2]
    eqN[i] = equilibrium_Normal!(pop_N, m, diff).N
end 
Plots.plot(x,eq)
Plots.plot!(x,eqv)
Plots.plot!(x,eqN)
