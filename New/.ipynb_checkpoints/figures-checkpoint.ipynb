# %% [markdown]
# # Figures

# %%
include("AgeStructuredModels.jl")
include("DemographicParameters.jl")
include("AgeTraitStructuredModels.jl")
include("StockRecruitCurves.jl")
using Plots
theme(:wong2)

# initialize demographic model - paramters loaded from DemographicParameters.jl 
# see tests in "TestDemographicParametersparams.ipynb"
mod = AgeStructuredModels.init(150,DemographicParameters.Smyth_2016_sr,DemographicParameters.Smyth_2016_survival,
    DemographicParameters.Smyth_16_F_vec)

Rstar = AgeStructuredModels.compute_Rstar(mod)
k = 3.0


# set base genetic paramters
Vle = 1.0
θ = 0.0
s = 0.1
min = -5
max = 20 
Δz = 0.15

# set base paramters for propogated individuals 
μ_im = 5.0
R_im = 0.5 * Rstar  # 50% natrual recrutment 

# initialize coupled genetic-demogrpahic model 
pop = AgeTraitStructuredModels.init(mod,Vle, θ, s, min, max, Δz)
StockRecruitCurves.update_BevetonHolt_k!(pop.ageStructure.SRCurve, k)
im = AgeTraitStructuredModels.init_imigrants(pop, R_im, μ_im)
print(" ")

# %%
AgeTraitStructuredModels.reset_immigrants_RRS!(im,pop, 0.1, 0.01)
Plots.plot(im.grid,im.trait)

# %%
function equilibrium_RRS(population, immigrants, update!,before, prop_im, RRS,s)
    AgeTraitStructuredModels.reset!(population,s)
    Rstar = AgeStructuredModels.compute_Rstar(population.ageStructure)
    Estar = AgeStructuredModels.compute_Rstar(population.ageStructure) * AgeStructuredModels.LEP(population.ageStructure)
    if before  
        AgeTraitStructuredModels.reset_immigrants_RRS!(immigrants,population, prop_im*Estar, RRS)
    else
        AgeTraitStructuredModels.reset_immigrants_RRS!(immigrants,population, prop_im*Rstar, RRS)
    end
    return AgeTraitStructuredModels.equilibrium(population, update!, immigrants)
end 

function min_outcomes_RRS(population, immigrants, update!,before, T, prop_im, RRS,s)
    AgeTraitStructuredModels.reset!(population,s)
    Rstar = AgeStructuredModels.compute_Rstar(population.ageStructure)
    Estar = AgeStructuredModels.compute_Rstar(population.ageStructure) * AgeStructuredModels.LEP(population.ageStructure)
    if before  
        AgeTraitStructuredModels.reset_immigrants_RRS!(immigrants,population, prop_im*Estar, RRS)
    else
        AgeTraitStructuredModels.reset_immigrants_RRS!(immigrants,population, prop_im*Rstar, RRS)
    end
    return AgeTraitStructuredModels.min_outcomes(population, update!, immigrants, T)
end 

p_im = 0.1
RRS = 0.5
T = 10
min_outcomes_RRS(pop, im, AgeTraitStructuredModels.time_step_DSI!, false, T, p_im, RRS,0.1)
# Out:
# (0.9521753210615147, 326.2044504658202, 0.04803963762319689, 0.9612329459954638)

# %%
using SharedArrays
p_im = 0.05:0.025:0.5
RRS = 0.01:0.2:0.81
s = 0.1
Ws1 = SharedArrays{Float64}(length(p_im), length(RRS))#zeros(length(p_im), length(RRS))
SSBs1 = SharedArrays{Float64}(length(p_im), length(RRS))#zeros(length(p_im), length(RRS))

for i in 1:length(p_im) #Threads.@threads 
    print(i/length(p_im))
    print(" ")
    Threads.@threads for j in 1:length(RRS)
        p_im = 0.05:0.025:0.5
        RRS = 0.01:0.2:0.81
        s = 0.1
        Ws1[i,j], SSBs1[i,j] = equilibrium_RRS(pop, im, AgeTraitStructuredModels.time_step_DSI!, false, p_im[i], RRS[j],s)[1:2]
    end 
end
# Out:
# 0.05263157894736842

# %%
s = 0.05
Ws2 = zeros(length(p_im), length(RRS))
SSBs2 = zeros(length(p_im), length(RRS))
for i in 1:length(p_im) #Threads.@threads 
    print(i/length(p_im))
    print(" ")
    for j in 1:length(RRS)
        Ws2[i,j], SSBs2[i,j] = equilibrium_RRS(pop, im, AgeTraitStructuredModels.time_step_DSI!, false, p_im[i], RRS[j],s)[1:2]
    end 
end
# Out:
# 0.05263157894736842 0.10526315789473684 0.15789473684210525 0.21052631578947367 0.2631578947368421 0.3157894736842105 0.3684210526315789
# InterruptException:
#
# Stacktrace:
#  [1] broadcasted
#    @ ./broadcast.jl:1317 [inlined]
#  [2] broadcasted(::Function, ::Vector{Float64}, ::Float64)
#    @ Base.Broadcast ./broadcast.jl:1315
#  [3] reproduction(population::Main.AgeTraitStructuredModels.population)
#    @ Main.AgeTraitStructuredModels ~/github/domestication_selection_model/New/AgeTraitStructuredModels.jl:261
#  [4] time_step_DSI!(population::Main.AgeTraitStructuredModels.population, immigrants::Main.AgeTraitStructuredModels.immigrants)
#    @ Main.AgeTraitStructuredModels ~/github/domestication_selection_model/New/AgeTraitStructuredModels.jl:432
#  [5] equilibrium(population::Main.AgeTraitStructuredModels.population, update!::typeof(Main.AgeTraitStructuredModels.time_step_DSI!), immigrants::Main.AgeTraitStructuredModels.immigrants)
#    @ Main.AgeTraitStructuredModels ~/github/domestication_selection_model/New/AgeTraitStructuredModels.jl:640
#  [6] equilibrium_RRS(population::Main.AgeTraitStructuredModels.population, immigrants::Main.AgeTraitStructuredModels.immigrants, update!::Function, before::Bool, prop_im::Float64, RRS::Float64, s::Float64)
#    @ Main ./In[3]:10
#  [7] top-level scope
#    @ ./In[4]:11
#  [8] eval
#    @ ./boot.jl:360 [inlined]
#  [9] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
p1 = Plots.plot(p_im, Ws1[:,1], label = string("RRS = ",RRS[1] ),legend =:none)
p2 = Plots.plot(p_im, SSBs1[:,1], label = string("RRS = ",RRS[1] ),legend =:none)
p3 = Plots.plot(p_im, Ws2[:,1], label = string("RRS = ",RRS[1] ),legend =:outerbottom)
p4 = Plots.plot(p_im, SSBs2[:,1], label = string("RRS = ",RRS[1] ),legend =:outerbottom)
for i in 2:length(RRS)
    Plots.plot!(p1,p_im, Ws1[:,i], label = string("RRS = ",RRS[i] ))
    Plots.plot!(p2,p_im, SSBs1[:,i], label = string("RRS = ",RRS[i] ))
    Plots.plot!(p3,p_im, Ws2[:,i], label = string("RRS = ",RRS[i] ))
    Plots.plot!(p4,p_im, SSBs2[:,i], label = string("RRS = ",RRS[i] ))
end
plot(p1,p2,p3,p4)
# Out:
# UndefVarError: Ws2 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:3
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
p_im = 0.25
RRS = 0.01:0.2:0.81

Tgen =  DemographicParameters.Smyth_2016_T1
T = Tgen.*2 .^(-2:0.5:6)


W = zeros(length(T), length(RRS))
SSB = zeros(length(T), length(RRS))

for i in 1:length(T)
    print(i/length(T))
    print(" ")
    for j in 1:length(RRS)
        W[i,j], SSB[i,j] = min_outcomes_RRS(pop, im, AgeTraitStructuredModels.time_step_DSI!, false, T[i], p_im, RRS[j])[1:2]
    end 
end 
Plots.heatmap(W)
# Out:
# 0.058823529411764705 0.11764705882352941 0.17647058823529413 0.23529411764705882 0.29411764705882354 0.35294117647058826 0.4117647058823529 0.47058823529411764 0.5294117647058824 0.5882352941176471 0.6470588235294118 0.7058823529411765 0.7647058823529411 0.8235294117647058 0.8823529411764706 0.9411764705882353 1.0

# %%
p1 = Plots.plot(T./Tgen, W[:,1], label = string("RRS = ",RRS[1] ),legend =:outerbottom)
p2 = Plots.plot(T./Tgen, SSB[:,1], label = string("RRS = ",RRS[1] ),legend =:outerbottom)
for i in 2:length(RRS)
    Plots.plot!(p1,T./Tgen, W[:,i], label = string("RRS = ",RRS[i] ))
    Plots.plot!(p2,T./Tgen, SSB[:,i], label = string("RRS = ",RRS[i] ))
end
plot(p1,p2)

# %%
RRS = 0.01:0.2:0.81
p_im = 0.2
min_outcomes_RRS(pop, im, AgeTraitStructuredModels.time_step_DSI!, false, 100, p_im, RRS[2])[1:2]
# Out:
# (0.819212324241889, 294.1826088758981)

# %%
min_outcomes_RRS(pop, im, AgeTraitStructuredModels.time_step_DSI!, false, 2, p_im, RRS[2])[1:2]
# Out:
# (0.25876551466557884, 121.98874523321628)

# %%
using IJulia
installkernel("Julia (6 threads)", env=Dict("JULIA_NUM_THREADS"=>"6"))
# Out:
# ┌ Info: Installing Julia (6 threads) kernelspec in /Users/johnbuckner/Library/Jupyter/kernels/julia-(6-threads)-1.6
# └ @ IJulia /Users/johnbuckner/.julia/packages/IJulia/e8kqU/deps/kspec.jl:94
# "/Users/johnbuckner/Library/Jupyter/kernels/julia-(6-threads)-1.6"
